# %% [markdown]
# <a href="https://colab.research.google.com/github/srulikbd/Deep-Learning/blob/master/DALL_E_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dalle-pytorch --upgrade
# Out:
# ...
#      |████████████████████████████████| 1.4MB 5.8MB/s
# ...
#      |████████████████████████████████| 51kB 8.0MB/s
# ...
#      |████████████████████████████████| 1.7MB 57.1MB/s
# ...
#      |████████████████████████████████| 71kB 11.4MB/s
# ...
#      |████████████████████████████████| 2.1MB 49.6MB/s
# ...
#      |████████████████████████████████| 3.3MB 50.2MB/s
# ...
#      |████████████████████████████████| 849kB 56.9MB/s
# ...
#      |████████████████████████████████| 901kB 56.7MB/s
# ...
#      |████████████████████████████████| 61kB 9.0MB/s
# ...
#      |████████████████████████████████| 21.6MB 1.3MB/s
# ...
#      |████████████████████████████████| 645kB 48.6MB/s
# ...
#      |████████████████████████████████| 112kB 51.7MB/s
# ...
#      |████████████████████████████████| 184kB 38.9MB/s
# ...
#      |████████████████████████████████| 829kB 55.5MB/s
# ...
#      |████████████████████████████████| 1.9MB 47.8MB/s
# ...
#      |████████████████████████████████| 747kB 52.0MB/s
# ...
#      |████████████████████████████████| 1.3MB 48.9MB/s
# ...

# %%
# !pip install wandb
import wandb
# !wandb login
# Out:
# ...
#      |████████████████████████████████| 2.1MB 5.4MB/s
# ...
#      |████████████████████████████████| 163kB 25.3MB/s
# ...
#      |████████████████████████████████| 102kB 10.0MB/s
# ...
#      |████████████████████████████████| 133kB 21.7MB/s
# ...
#      |████████████████████████████████| 71kB 10.0MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-cp37-none-any.whl size=8786 sha256=bddf6531e64433c240ddfc8fb5030c927501d639f223979bdf217886647ff795
#   Stored in directory: /root/.cache/pip/wheels/0b/04/79/c3b0c3a0266a3cb4376da31e5bfe8bba0c489246968a68e843
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp37-none-any.whl size=6489 sha256=c2107a4cd8dbaff02f83d390a2c8aee17989ddcd861008091cf34ebe14e6718e
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
# Successfully built pathtools subprocess32
# ...
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# ...

# %%
# !pip install gdown
# Out:
# 448920e90bc8564b76c553e3aec46c092bbc3078
# ...

# %% [markdown]
# ### For demonstration, purposes, we will be using the Caltech-UCSD Birds dataset (CUB)

# %%
# !gdown https://drive.google.com/uc?id=0B3y_msrWZaXLT1BZdVdycDY5TEE
# !gdown https://drive.google.com/uc?id=1hbzc_P1FuxMkcabkgn9ZKinBwW683j45
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=0B3y_msrWZaXLT1BZdVdycDY5TEE
# To: /content/birds.zip
# 613MB [00:07, 79.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1hbzc_P1FuxMkcabkgn9ZKinBwW683j45
# To: /content/CUB_200_2011.tgz
# 1.15GB [00:18, 62.1MB/s]

# %%
#!rm -rf birds CUB_200_2011
# !unzip birds.zip
# !tar zxvf CUB_200_2011.tgz
# Out:
# Streaming output truncated to the last 5000 lines.
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0004_111989.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0068_113247.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0127_111935.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0094_112773.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0028_113217.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0126_110959.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0007_111029.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0096_111519.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0120_113001.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0010_112678.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0025_111669.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0084_111300.jpg
# CUB_200_2011/images/118.House_Sparrow/House_Sparrow_0002_112905.jpg
# ...

# %%
# !git clone https://github.com/lucidrains/DALLE-pytorch.git

# %%
# %cd DALLE-pytorch/

# %%
# !pip install dalle_pytorch

# %%
# !cp -a '/content/birds/text_c10/.' '/content/sample_data/'

# %%
# !python /content/DALLE-pytorch/train_dalle.py --taming --image_text_folder '/content/CUB_200_2011/images/'
# Out:
# Streaming output truncated to the last 5000 lines.
# 2 1400 loss - 5.069046974182129
# 2 1410 loss - 5.065750598907471
# 2 1420 loss - 5.0775532722473145
# 2 1430 loss - 4.9973344802856445
# 2 1440 loss - 5.005105972290039
# 2 1450 loss - 4.7445268630981445
# 2 1460 loss - 4.755613803863525
# 2 1470 loss - 5.091518878936768
# 2 1480 loss - 4.96561861038208
# 2 1490 loss - 4.841802597045898
# 2 1500 loss - 4.694370269775391
# 2 1510 loss - 5.153411865234375
# 2 1520 loss - 4.830661773681641
# 2 1530 loss - 4.908207893371582
# 2 1540 loss - 4.641330718994141
# 2 1550 loss - 5.083052158355713
# 2 1560 loss - 5.0904459953308105
# 2 1570 loss - 5.002631187438965
# 2 1580 loss - 5.129645347595215
# 2 1590 loss - 4.804321765899658
# 2 1600 loss - 4.745042324066162
# 2 1610 loss - 4.569188594818115
# 2 1620 loss - 4.611509323120117
# 2 1630 loss - 5.165185451507568
# 2 1640 loss - 4.731046199798584
# 2 1650 loss - 4.943287372589111
# 2 1660 loss - 4.95961332321167
# ...

# %%
# %cd /root/.cache/torch/hub/checkpoints/
# Out:
# /root/.cache/torch/hub/checkpoints

# %%
# !where vae.pt
# Out:
# /bin/bash: where: command not found
